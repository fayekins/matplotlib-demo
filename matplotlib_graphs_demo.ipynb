# %%
from matplotlib import pyplot as plt 
from pydantic import BaseModel

# %%
import json
from pathlib import Path

# %%
class Pair(BaseModel):
    x: float
    y: float


class Series (BaseModel):
    series: str
    data: list[Pair]

# %%
source_path = Path.cwd().parent.parent / "sagemaker-user" / "data" / "anscombe.json"
with source_path.open() as source_file:
    all_data = json.load(source_file)
    [data['series'] for data in all_data]

# %%
clean_data = [Series.model_validate(d) for d in all_data]

# %%
clean_data[0]
# Out:
# Series(series='I', data=[Pair(x=10.0, y=8.04), Pair(x=8.0, y=6.95), Pair(x=13.0, y=7.58), Pair(x=9.0, y=8.81), Pair(x=11.0, y=8.33), Pair(x=14.0, y=9.96), Pair(x=6.0, y=7.24), Pair(x=4.0, y=4.26), Pair(x=12.0, y=10.84), Pair(x=7.0, y=4.82), Pair(x=5.0, y=5.68)])

# %%
quartet = {s.series: s for s in clean_data}

# %%
x = [p.x for p in quartet['I'].data]
y = [p.y for p in quartet['I'].data]

# %%
plt.scatter(x, y)
plt.title(f"Series {quartet['I'].series}")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = [p.x for p in quartet['II'].data]
y = [p.y for p in quartet['II'].data]

# %%
plt.scatter(x, y)
plt.title(f"Series {quartet['III'].series}")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = [p.x for p in quartet['III'].data]
y = [p.y for p in quartet['III'].data]

# %%
plt.scatter(x, y)
plt.title(f"Series {quartet['III'].series}")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = [p.x for p in quartet['IV'].data]
y = [p.y for p in quartet['IV'].data]

# %%
plt.scatter(x, y)
plt.title(f"Series {quartet['IV'].series}")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
